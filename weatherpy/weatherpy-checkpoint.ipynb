# %% [markdown]
# # Weatherpy

# %%
# Dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_key import weather_api_key
temp_units = "imperial"

# Incorporate citipy to determine latitude and longitude
from citi import citipy

# output File (CSV)
output_data_file = "output_data/weather_df.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   
    # If city is unique, then add city to list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %%
# Perform API Calls
# perform weather check on each city

base_url = "http://api.openweathermap.org/data/2.5/weather?"
query = base_url + "appid=" + weather_api_key + "&units=imperial" + "&q=" + city

# set lists for dataframe
record = 0
city_name = []
country = []
dates = []
cloudinesses = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []



# loop for creating dataframe
for city in cities:
    record +=1
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    query = base_url + "appid=" + weather_api_key + "&units=imperial" + "&q=" + city
    response = requests.get(query)
    response_json = response.json()
    if (str(response) == "<Response [200]>"): 
        print(f"Processing Record {record}: {city}")
        city_name.append(response_json["name"])
        cloudinesses.append(response_json["clouds"]["all"])
        country.append(response_json["sys"]["country"])
        dates.append(response_json["dt"])
        humidities.append(response_json["main"]["humidity"])
        lats.append(response_json["coord"]["lat"])
        lngs.append(response_json["coord"]["lon"])
        max_temps.append(response_json["main"]["temp_max"])
        wind_speeds.append(response_json["wind"]["speed"])
    else:
        print("Can't find city, skipping...")
    
    time.sleep(1)
    
print("-------------------------\nData Retrieval completed\n-----------------")
# Out:
# Processing Record 1: rikitea
# Processing Record 2: barrow
# Processing Record 3: horizontina
# Processing Record 4: upata
# Can't find city, skipping...
# Processing Record 6: kingaroy
# Processing Record 7: labuhan
# Processing Record 8: pacific grove
# Processing Record 9: grootfontein
# Processing Record 10: busselton
# Can't find city, skipping...
# Can't find city, skipping...
# Processing Record 13: hasaki
# Processing Record 14: port alfred
# Processing Record 15: jacareacanga
# Processing Record 16: torbay
# Processing Record 17: costinesti
# Processing Record 18: port elizabeth
# Processing Record 19: yangambi
# Processing Record 20: liverpool
# Processing Record 21: port macquarie
# Processing Record 22: ushuaia
# Processing Record 23: nikolskoye
# Processing Record 24: botucatu
# Processing Record 25: beloha
# Processing Record 26: bonthe
# Processing Record 27: margate
# Processing Record 28: albany
# Processing Record 29: georgetown
# Processing Record 30: amapa
# Processing Record 31: hermanus
# Processing Record 32: carutapera
# Processing Record 33: tacoronte
# Can't find city, skipping...
# Processing Record 35: carnarvon
# Processing Record 36: batemans bay
# Processing Record 37: atuona
# Processing Record 38: norman wells
# Processing Record 39: yellowknife
# Processing Record 40: urusha
# Processing Record 41: fort nelson
# Processing Record 42: flinders
# Processing Record 43: mahebourg
# Processing Record 44: hobart
# Processing Record 45: saint-georges
# Processing Record 46: hilo
# Processing Record 47: lavrentiya
# Processing Record 48: haines junction
# Processing Record 49: tasiilaq
# Processing Record 50: bethel
# Processing Record 51: abrantes
# Processing Record 52: guerrero negro
# Processing Record 53: karema
# Processing Record 54: east london
# Processing Record 55: berlevag
# Processing Record 56: playa vicente
# Processing Record 57: chengde
# Processing Record 58: vanavara
# Processing Record 59: juba
# Processing Record 60: pocone
# Processing Record 61: babai
# Processing Record 62: ribeira grande
# Processing Record 63: mahon
# Processing Record 64: narsaq
# Processing Record 65: ballina
# Processing Record 66: yinchuan
# Processing Record 67: epe
# Processing Record 68: kodiak
# Processing Record 69: necochea
# Processing Record 70: cherskiy
# Processing Record 71: arraial do cabo
# Processing Record 72: lebu
# Processing Record 73: avarua
# Processing Record 74: nyurba
# Processing Record 75: coquimbo
# Processing Record 76: eyl
# Processing Record 77: cape town
# Processing Record 78: hithadhoo
# Processing Record 79: bluff
# Processing Record 80: kapaa
# Processing Record 81: whitehorse
# Processing Record 82: ostrovnoy
# Processing Record 83: taoudenni
# Can't find city, skipping...
# Processing Record 85: kathmandu
# Processing Record 86: butaritari
# Processing Record 87: labuan
# Processing Record 88: ferkessedougou
# Processing Record 89: vaini
# Processing Record 90: bereda
# Processing Record 91: gainesville
# Processing Record 92: padang
# Can't find city, skipping...
# Processing Record 94: izumo
# Processing Record 95: seoul
# Processing Record 96: thompson
# Processing Record 97: castro
# Can't find city, skipping...
# Processing Record 99: vardo
# Can't find city, skipping...
# Processing Record 101: tazovskiy
# Processing Record 102: new norfolk
# Processing Record 103: goderich
# Processing Record 104: sacama
# Processing Record 105: bani walid
# Can't find city, skipping...
# Processing Record 107: san carlos de bariloche
# Processing Record 108: punta arenas
# Processing Record 109: mogadishu
# Processing Record 110: strezhevoy
# Processing Record 111: uribia
# Processing Record 112: sao filipe
# Processing Record 113: esperance
# Processing Record 114: hanyang
# Processing Record 115: louisville
# Processing Record 116: jalu
# Processing Record 117: cidreira
# Processing Record 118: asau
# Processing Record 119: saldanha
# Processing Record 120: yatou
# Processing Record 121: victoria
# Processing Record 122: cayenne
# Processing Record 123: ojinaga
# Can't find city, skipping...
# Processing Record 125: mawlaik
# Processing Record 126: ulaanbaatar
# Processing Record 127: ponta do sol
# Processing Record 128: lorengau
# Processing Record 129: puerto ayora
# Processing Record 130: jamestown
# Processing Record 131: beira
# Processing Record 132: mataura
# Processing Record 133: banda aceh
# Processing Record 134: siguiri
# Processing Record 135: heihe
# Processing Record 136: san luis de la paz
# Processing Record 137: fare
# Processing Record 138: cabo san lucas
# Processing Record 139: khatanga
# Processing Record 140: sao joao da barra
# Processing Record 141: kalanguy
# Processing Record 142: aksu
# Processing Record 143: saint-philippe
# Can't find city, skipping...
# Processing Record 145: los llanos de aridane
# Processing Record 146: ancud
# Processing Record 147: nalut
# Processing Record 148: souillac
# Processing Record 149: belmonte
# Processing Record 150: jiangyou
# Processing Record 151: mbuguni
# Processing Record 152: nizhniy kuranakh
# Processing Record 153: moerai
# Processing Record 154: totness
# Processing Record 155: kudahuvadhoo
# Processing Record 156: sidi ali
# Processing Record 157: kidal
# Processing Record 158: barguzin
# Can't find city, skipping...
# Can't find city, skipping...
# Processing Record 161: brigantine
# Processing Record 162: klaksvik
# Processing Record 163: korla
# Processing Record 164: upernavik
# Processing Record 165: chardara
# Processing Record 166: socorro
# Processing Record 167: grindavik
# Processing Record 168: provideniya
# Processing Record 169: acajutla
# Processing Record 170: alofi
# Processing Record 171: buin
# Processing Record 172: dikson
# Processing Record 173: mar del plata
# Processing Record 174: pemberton
# Processing Record 175: vanimo
# Processing Record 176: barcelos
# Processing Record 177: lompoc
# Processing Record 178: kahului
# Processing Record 179: bredasdorp
# Processing Record 180: leningradskiy
# Processing Record 181: sadovoye
# Processing Record 182: praia da vitoria
# Processing Record 183: nelson bay
# Processing Record 184: comodoro rivadavia
# Processing Record 185: airai
# Can't find city, skipping...
# Processing Record 187: nieuw amsterdam
# Processing Record 188: birobidzhan
# Can't find city, skipping...
# Processing Record 190: codrington
# Processing Record 191: kavaratti
# Processing Record 192: yate
# Processing Record 193: qingyuan
# Processing Record 194: namibe
# Processing Record 195: tierralta
# Processing Record 196: bengkulu
# Processing Record 197: poum
# Processing Record 198: olafsvik
# Processing Record 199: tuatapere
# Processing Record 200: itarema
# Processing Record 201: dire dawa
# Processing Record 202: buala
# Processing Record 203: menongue
# Processing Record 204: hamilton
# Can't find city, skipping...
# Processing Record 206: tuktoyaktuk
# Processing Record 207: wewak
# Processing Record 208: nanortalik
# Processing Record 209: hopeman
# Processing Record 210: chokurdakh
# Processing Record 211: muroto
# Processing Record 212: taos
# Processing Record 213: moree
# Processing Record 214: volksrust
# Processing Record 215: mattru
# Processing Record 216: shanhetun
# Processing Record 217: groningen
# Processing Record 218: diamantino
# Processing Record 219: najran
# Processing Record 220: ponta delgada
# Processing Record 221: bulgan
# Processing Record 222: katsuura
# Can't find city, skipping...
# Processing Record 224: vidim
# Processing Record 225: zhigansk
# Can't find city, skipping...
# Processing Record 227: coihaique
# Processing Record 228: maralal
# Processing Record 229: jardim
# Processing Record 230: saint george
# Processing Record 231: tezu
# Processing Record 232: nizwa
# Processing Record 233: pevek
# Processing Record 234: luderitz
# Can't find city, skipping...
# Processing Record 236: rawson
# Processing Record 237: matara
# Processing Record 238: wexford
# Processing Record 239: tabou
# Processing Record 240: husavik
# Processing Record 241: batticaloa
# Processing Record 242: vila velha
# Processing Record 243: rovnoye
# Processing Record 244: kruisfontein
# Processing Record 245: iracoubo
# Can't find city, skipping...
# Processing Record 247: mujiayingzi
# Processing Record 248: antalaha
# Processing Record 249: te anau
# Processing Record 250: bucsani
# Processing Record 251: egvekinot
# Processing Record 252: modra
# Processing Record 253: la union
# Can't find city, skipping...
# Processing Record 255: qaanaaq
# Processing Record 256: hirara
# Processing Record 257: naryan-mar
# Can't find city, skipping...
# Processing Record 259: nurota
# Processing Record 260: hella
# Processing Record 261: hongjiang
# Processing Record 262: varzea grande
# Processing Record 263: ugleuralskiy
# Processing Record 264: santa maria
# Processing Record 265: camacha
# Processing Record 266: lagoa
# Processing Record 267: yerofey pavlovich
# Processing Record 268: basco
# Processing Record 269: grand gaube
# Processing Record 270: galbshtadt
# Processing Record 271: salalah
# Processing Record 272: shitanjing
# Processing Record 273: khandyga
# Processing Record 274: sitka
# Processing Record 275: gat
# Processing Record 276: xuddur
# Processing Record 277: uga
# Processing Record 278: hami
# Can't find city, skipping...
# Processing Record 280: aklavik
# Processing Record 281: coolum beach
# Processing Record 282: aquiraz
# Processing Record 283: kozan
# Processing Record 284: shache
# Processing Record 285: kavieng
# Processing Record 286: praxedis guerrero
# Processing Record 287: finnsnes
# Processing Record 288: ouegoa
# Processing Record 289: rocha
# Processing Record 290: acapulco
# Processing Record 291: jetpur
# Processing Record 292: ginir
# Processing Record 293: mehamn
# Processing Record 294: murray bridge
# Processing Record 295: tommot
# Processing Record 296: komsomolskiy
# Processing Record 297: kamenka
# Processing Record 298: matay
# Can't find city, skipping...
# Processing Record 300: college
# Processing Record 301: punta de piedra
# Processing Record 302: horsham
# Processing Record 303: hambantota
# Processing Record 304: sola
# Can't find city, skipping...
# Processing Record 306: chapais
# Processing Record 307: northam
# Processing Record 308: jerome
# Processing Record 309: kabanjahe
# Processing Record 310: saskylakh
# Processing Record 311: luang prabang
# Processing Record 312: sishui
# Processing Record 313: lindas
# Processing Record 314: the valley
# Processing Record 315: sao sebastiao do paraiso
# Processing Record 316: coos bay
# Processing Record 317: laguna
# Processing Record 318: isangel
# Processing Record 319: sabang
# Processing Record 320: adrar
# Processing Record 321: shimoda
# Processing Record 322: biu
# Processing Record 323: indaial
# Processing Record 324: maple creek
# Processing Record 325: kalocsa
# Processing Record 326: mahanoro
# Processing Record 327: mariestad
# Processing Record 328: cervo
# Processing Record 329: glotovka
# Processing Record 330: lastoursville
# Processing Record 331: faanui
# Processing Record 332: kapurthala
# Processing Record 333: pyshchug
# Processing Record 334: sebastian
# Processing Record 335: xining
# Processing Record 336: toktogul
# Processing Record 337: ketchikan
# Processing Record 338: ugoofaaru
# Processing Record 339: hualmay
# Processing Record 340: bentiu
# Processing Record 341: talnakh
# Processing Record 342: kashi
# Processing Record 343: sunel
# Processing Record 344: gongzhuling
# Processing Record 345: baneh
# Processing Record 346: sao gotardo
# Processing Record 347: sao felix do xingu
# Processing Record 348: mandalgovi
# Can't find city, skipping...
# Processing Record 350: kaliua
# Processing Record 351: alugan
# Can't find city, skipping...
# Processing Record 353: tiksi
# Processing Record 354: loding
# Processing Record 355: carballo
# Processing Record 356: umba
# Processing Record 357: berasia
# Processing Record 358: liwale
# Processing Record 359: calabozo
# Processing Record 360: omsukchan
# Processing Record 361: bourail
# Processing Record 362: hervey bay
# Processing Record 363: villa sandino
# Processing Record 364: bowen
# Processing Record 365: zaraza
# Can't find city, skipping...
# Processing Record 367: qianjiang
# Processing Record 368: atbasar
# Processing Record 369: ahipara
# Processing Record 370: antofagasta
# Processing Record 371: tual
# Processing Record 372: altay
# Processing Record 373: agirish
# Processing Record 374: lakes entrance
# Processing Record 375: bilibino
# Processing Record 376: kemijarvi
# Processing Record 377: skelleftea
# Processing Record 378: batie
# Processing Record 379: kyzyl-suu
# Processing Record 380: preobrazheniye
# Processing Record 381: uyuni
# Processing Record 382: kalmunai
# Can't find city, skipping...
# Processing Record 384: sao paulo de olivenca
# Processing Record 385: dabakala
# Processing Record 386: bambous virieux
# Processing Record 387: san cristobal
# Processing Record 388: salamanca
# Processing Record 389: avera
# Can't find city, skipping...
# Processing Record 391: lahaina
# Processing Record 392: north bend
# Processing Record 393: mount gambier
# Processing Record 394: lensk
# Processing Record 395: kurilsk
# Processing Record 396: robertsganj
# Processing Record 397: ozinki
# Processing Record 398: iqaluit
# Processing Record 399: constitucion
# Processing Record 400: moron
# Processing Record 401: filadelfia
# Processing Record 402: port-cartier
# Processing Record 403: aiquile
# Processing Record 404: eureka
# Processing Record 405: tapia
# Processing Record 406: tono
# Processing Record 407: les cayes
# Processing Record 408: maumere
# Processing Record 409: imbituba
# Can't find city, skipping...
# Can't find city, skipping...
# Processing Record 412: auki
# Processing Record 413: juneau
# Processing Record 414: boende
# Processing Record 415: lata
# Processing Record 416: swakopmund
# Processing Record 417: clyde river
# Processing Record 418: felanitx
# Can't find city, skipping...
# Processing Record 420: meulaboh
# Can't find city, skipping...
# Processing Record 422: nabire
# Processing Record 423: voiron
# Processing Record 424: inta
# Processing Record 425: pilar
# Processing Record 426: maneadero
# Can't find city, skipping...
# Processing Record 428: sao miguel do guama
# Processing Record 429: madras
# Processing Record 430: kutum
# Can't find city, skipping...
# Processing Record 432: marovoay
# Processing Record 433: hobyo
# Processing Record 434: iquitos
# Processing Record 435: lima
# Processing Record 436: sangar
# Processing Record 437: ambovombe
# Processing Record 438: mragowo
# Processing Record 439: may pen
# Processing Record 440: sungaipenuh
# Processing Record 441: karatuzskoye
# Processing Record 442: dzerzhinskoye
# Processing Record 443: kathu
# Processing Record 444: guiyang
# Processing Record 445: port hawkesbury
# Processing Record 446: saint-augustin
# Processing Record 447: taltal
# Processing Record 448: svobodnyy
# Processing Record 449: fort-shevchenko
# Processing Record 450: seynod
# Processing Record 451: kununurra
# Processing Record 452: itaituba
# Processing Record 453: mecca
# Processing Record 454: naze
# Processing Record 455: la ronge
# Processing Record 456: port lincoln
# Processing Record 457: ossora
# Processing Record 458: svetlyy
# Processing Record 459: baiyin
# Processing Record 460: almaznyy
# Processing Record 461: zernograd
# Processing Record 462: ninghai
# Processing Record 463: faya
# Processing Record 464: vaitape
# Processing Record 465: dingle
# Processing Record 466: dunedin
# Processing Record 467: rubtsovsk
# Processing Record 468: leova
# Processing Record 469: ambunti
# Processing Record 470: zhanaozen
# Processing Record 471: coahuayana
# Processing Record 472: merrill
# Processing Record 473: luangwa
# Processing Record 474: hoa binh
# Can't find city, skipping...
# Processing Record 476: winslow
# Processing Record 477: tayu
# Processing Record 478: bac lieu
# Processing Record 479: jiuquan
# Processing Record 480: turayf
# Processing Record 481: tres arroyos
# Processing Record 482: maracaju
# Processing Record 483: uvalde
# Can't find city, skipping...
# Processing Record 485: fortuna
# Processing Record 486: bathsheba
# Processing Record 487: huilong
# Processing Record 488: ifanadiana
# Processing Record 489: paamiut
# Can't find city, skipping...
# Processing Record 491: bandarbeyla
# Processing Record 492: la rioja
# Processing Record 493: tautira
# Processing Record 494: anadyr
# Processing Record 495: salihorsk
# Processing Record 496: nantucket
# Processing Record 497: jaroslaw
# Processing Record 498: chumikan
# Processing Record 499: bosaso
# Processing Record 500: uravakonda
# Processing Record 501: mange
# Processing Record 502: olinda
# Processing Record 503: fairbanks
# Processing Record 504: mae chan
# Processing Record 505: lanzhou
# Processing Record 506: atambua
# Processing Record 507: dudinka
# Processing Record 508: breves
# Processing Record 509: barberton
# Processing Record 510: longyearbyen
# Processing Record 511: portland
# Processing Record 512: minna
# Processing Record 513: lieksa
# Processing Record 514: luwuk
# Processing Record 515: soe
# Processing Record 516: sinnamary
# Processing Record 517: dubrovka
# Processing Record 518: srandakan
# Processing Record 519: kaeo
# Processing Record 520: zhaodong
# Processing Record 521: banswada
# Processing Record 522: puka
# Can't find city, skipping...
# Processing Record 524: tchaourou
# Processing Record 525: kuusamo
# Processing Record 526: grand-santi
# Processing Record 527: lewiston
# Processing Record 528: clarence town
# Processing Record 529: kenai
# Processing Record 530: tigil
# Can't find city, skipping...
# Processing Record 532: port hedland
# Processing Record 533: viedma
# Processing Record 534: kaitangata
# Processing Record 535: chibuto
# Processing Record 536: itaueira
# Processing Record 537: jonkoping
# Processing Record 538: baykit
# Processing Record 539: kouroussa
# Processing Record 540: yar-sale
# Processing Record 541: rio grande
# Processing Record 542: marawi
# Processing Record 543: omboue
# Processing Record 544: yonezawa
# Processing Record 545: lagos de moreno
# Processing Record 546: zaltan
# Processing Record 547: cockburn town
# Processing Record 548: altus
# Processing Record 549: bilma
# Processing Record 550: tlanalapan
# Processing Record 551: pathein
# Processing Record 552: honiara
# Processing Record 553: lyngseidet
# Processing Record 554: mugla
# Processing Record 555: fort abbas
# Processing Record 556: aykhal
# Processing Record 557: biltine
# Processing Record 558: chuy
# Processing Record 559: klyuchi
# Processing Record 560: santa rosa
# Processing Record 561: edson
# Processing Record 562: neepawa
# Processing Record 563: turbat
# Processing Record 564: hay river
# Processing Record 565: eston
# Processing Record 566: srikakulam
# Processing Record 567: boromo
# Processing Record 568: moncao
# Processing Record 569: huarmey
# Processing Record 570: santiago del estero
# Processing Record 571: muisne
# Can't find city, skipping...
# Can't find city, skipping...
# Processing Record 574: baruun-urt
# Processing Record 575: broome
# Processing Record 576: guilin
# Processing Record 577: husainabad
# Can't find city, skipping...
# Processing Record 579: manyana
# Processing Record 580: bud
# Processing Record 581: liaozhong
# Processing Record 582: havelock
# Processing Record 583: balaghat
# Processing Record 584: frontera
# Processing Record 585: fayaoue
# Processing Record 586: yichun
# Processing Record 587: batagay
# Processing Record 588: yurimaguas
# Processing Record 589: avesta
# Processing Record 590: severo-kurilsk
# Processing Record 591: zabol
# Processing Record 592: ilulissat
# Processing Record 593: green river
# Processing Record 594: uige
# Processing Record 595: san francisco
# Processing Record 596: pimenta bueno
# Processing Record 597: ankang
# Processing Record 598: formosa
# Can't find city, skipping...
# Processing Record 600: nyzhnya duvanka
# Processing Record 601: salta
# Processing Record 602: saint marys
# Processing Record 603: tura
# Processing Record 604: mayo
# Processing Record 605: geraldton
# Processing Record 606: birjand
# Processing Record 607: jinchang
# Can't find city, skipping...
# Processing Record 609: awjilah
# Can't find city, skipping...
# Processing Record 611: nishihara
# Processing Record 612: palwal
# Processing Record 613: belyy yar
# Processing Record 614: yulara
# Processing Record 615: brae
# Processing Record 616: hanko
# -------------------------
# Data Retrieval completed
# -----------------

# %%
# convert to dataframe

weather_dict = {
    "City" : city_name, 
    "Cloudiness" : cloudinesses,
    "Country" : country,
    "Date": dates,
    "Humidity" : humidities,
    "Lat" : lats,
    "Lng" : lngs,
    "Max Temp" : max_temps,
    "Wind Speed" : wind_speeds
    
}

weather_df = pd.DataFrame(weather_dict)
weather_df
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        Rikitea          55      PF  1583361189        72 -23.12 -134.97
# 1         Barrow           1      US  1583360386        93  71.29 -156.79
# 2    Horizontina          13      BR  1583361192        49 -27.63  -54.31
# 3          Upata          39      VE  1583361193        69   8.01  -62.40
# 4       Kingaroy          40      AU  1583361195        78 -26.53  151.83
# ..           ...         ...     ...         ...       ...    ...     ...
# 564       Palwal          90      IN  1583361938       100  28.15   77.33
# 565    Belyy Yar          34      RU  1583361940        73  53.60   91.39
# 566       Yulara           0      AU  1583361941        55 -25.24  130.99
# 567         Brae          85      GB  1583361942        86  60.40   -1.35
# 568        Hanko         100      FI  1583361943        90  59.83   22.95
#
#      Max Temp  Wind Speed
# 0       77.59       18.32
# 1      -29.20        3.36
# 2       71.28        2.39
# 3       76.24        9.53
# 4       78.01        8.05
# ..        ...         ...
# 564     60.80        8.05
# 565     24.80       11.18
# 566     62.60        4.70
# 567     41.00       11.41
# 568     37.00       11.99
#
# [569 rows x 9 columns]

# %%
# save to outputdata as csv file
weather_df.to_csv(output_data_file)

weather_df.count()
# Out:
# City          569
# Cloudiness    569
# Country       569
# Date          569
# Humidity      569
# Lat           569
# Lng           569
# Max Temp      569
# Wind Speed    569
# dtype: int64

# %% [markdown]
# # Latitude vs. Temperature Plot
#
# This plot exhibits the relationship between latittude and nax temperature in selected cities.
# It tells us that the closer a city is to the equator, the higher the temperature.

# %%
# plot the data
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], edgecolors = "black", facecolors = "orange")
plt.title("City Latitude vs. Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig1.png")
plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot
# This plot shows the relationship between latittude and humidity.
# It shows that cities south of the equator are more humid than the north of equator.

# %%
# plot the data
plt.scatter(weather_df["Lat"], weather_df["Humidity"], edgecolors = "black", facecolors = "green")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig2.png")
plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Plot
# Cloudiness doesn't seem to be affected by the equator.  There is no vivid relationship.

# %%
# plot the data
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], edgecolors = "black", facecolors = "lightblue")
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig3.png")
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot
# The below plot shows the relationship between latitude and wind speed.  It exhibits that southern parts are more windy than northern parts.

# %%
# plot the data
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], edgecolors = "black", facecolors = "purple")
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig4.png")
plt.show()

# %% [markdown]
# # Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames

#Northern Hemisphere (Lat > 0)
weather_df_north = weather_df[weather_df['Lat'] >= 0]

#Southern Hemisphere (Lat < 0)
weather_df_south = weather_df[weather_df['Lat'] < 0]

# %% [markdown]
# # Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = weather_df_north['Lat']
y_values = weather_df_north['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#plot data
lat_temp_regress = plt.scatter(x_values,y_values,marker='o',edgecolors='black', facecolors = "orange")
plt.plot(x_values,reg_values,"r-")
plt.annotate(line, xy=(0,30),fontsize=15,color='red')
plt.title("City Latitude (North) vs. Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig5.png")
plt.show()

#r2
print(f'r^2: {rvalue}')
# Out:
# r^2: -0.8861404686887961

# %% [markdown]
# # Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = weather_df_south['Lat']
y_values = weather_df_south['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#plot data
lat_temp_regress = plt.scatter(x_values,y_values,marker='o',edgecolors='black', facecolors = "orange")
plt.plot(x_values,reg_values,"r-")
plt.annotate(line, xy=(0,30),fontsize=15,color='red')
plt.title("City Latitude (North) vs. Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig5.png")
plt.show()

#r2
print(f'r^2: {rvalue}')
# Out:
# r^2: 0.4180174406930831

# %% [markdown]
# # Northern Hemisphere - Humdity vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = weather_df_north['Lat']
y_values = weather_df_north['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#plot data
lat_temp_regress = plt.scatter(x_values,y_values,marker='o',edgecolors='black', facecolors = "green")
plt.plot(x_values,reg_values,"r-")
plt.annotate(line, xy=(0,30),fontsize=15,color='red')
plt.title("City Latitude (North) vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig6.png")
plt.show()

#r2
print(f'r^2: {rvalue}')
# Out:
# r^2: 0.2698821680324408

# %% [markdown]
# # Southern Hemisphere - Humidity vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = weather_df_south['Lat']
y_values = weather_df_south['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#plot data
lat_temp_regress = plt.scatter(x_values,y_values,marker='o',edgecolors='black', facecolors = "green")
plt.plot(x_values,reg_values,"r-")
plt.annotate(line, xy=(0,30),fontsize=15,color='red')
plt.title("City Latitude (North) vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig6.png")
plt.show()

#r2
print(f'r^2: {rvalue}')
# Out:
# r^2: 0.3025967811534301

# %% [markdown]
# # Northern Hemisphere - Cloudiness vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = weather_df_north['Lat']
y_values = weather_df_north['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#plot data
lat_temp_regress = plt.scatter(x_values,y_values,marker='o',edgecolors='black', facecolors = "lightblue")
plt.plot(x_values,reg_values,"r-")
plt.annotate(line, xy=(0,30),fontsize=15,color='red')
plt.title("City Latitude (North) vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig7.png")
plt.show()

#r2
print(f'r^2: {rvalue}')
# Out:
# r^2: 0.28773479772625477

# %% [markdown]
# # Southern Hemisphere - Cloudiness vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = weather_df_south['Lat']
y_values = weather_df_south['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#plot data
lat_temp_regress = plt.scatter(x_values,y_values,marker='o',edgecolors='black', facecolors = "lightblue")
plt.plot(x_values,reg_values,"r-")
plt.annotate(line, xy=(0,30),fontsize=15,color='red')
plt.title("City Latitude (North) vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig7.png")
plt.show()

#r2
print(f'r^2: {rvalue}')
# Out:
# r^2: 0.38614948777711205

# %% [markdown]
# # Northern Hemisphere - Wind Speed vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = weather_df_north['Lat']
y_values = weather_df_north['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#plot data
lat_temp_regress = plt.scatter(x_values,y_values,marker='o',edgecolors='black', facecolors = "purple")
plt.plot(x_values,reg_values,"r-")
plt.annotate(line, xy=(0,30),fontsize=15,color='red')
plt.title("City Latitude (North) vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig8.png")
plt.show()

#r2
print(f'r^2: {rvalue}')
# Out:
# r^2: 0.12020476728574153

# %% [markdown]
# # Southern Hemisphere - Wind Speed vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = weather_df_south['Lat']
y_values = weather_df_south['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#plot data
lat_temp_regress = plt.scatter(x_values,y_values,marker='o',edgecolors='black', facecolors = "purple")
plt.plot(x_values,reg_values,"r-")
plt.annotate(line, xy=(0,30),fontsize=15,color='red')
plt.title("City Latitude (North) vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(b=True, which = "major", axis = "both", linestyle = "-", color="lightblue")
plt.savefig("Images/fig8.png")
plt.show()

#r2
print(f'r^2: {rvalue}')
# Out:
# r^2: -0.23434270915471894
